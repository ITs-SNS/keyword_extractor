# %%
import numpy as np
import itertools

from konlpy.tag import Hannanum
from sklearn.feature_extraction.text import CountVectorizer

# %%
hannanum = Hannanum()
stop_words="아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓"
stop_words=stop_words.split(' ')

# %%
doc_with_newlines = """
삼성전자의 모바일 애플리케이션 프로세서(AP) 신작 '엑시노스2200' 점유율 하락 원인은 무엇일까. 세트사들이 선택하지 않은 데는 수율, 가격 등 여러 요인이 있겠지만 성능 측면으로 보면 전작(엑시노스2100, 엑시노스980)에 비해 개선된 부분이 확실히 존재한다. 판단근거는 글로벌 IT부품 성능측정 기관인 '긱벤치(Geekbench5)' 등의 벤치마크 결과다. 멀티코어 벤치마크(CPU, GPU, 전력소비, 지속성, 앱구동 등) 점수가 상향된 것으로 나타났다.

특히 GPU 지속력을 강화했다는 건 전력소비를 낮추는데 유리하게 작용한다. 세트사 입장에선 충분히 가점요인이 될 수 있는 부분이다. 모바일AP 칩셋의 존재 이유도 사실상 전력소모 최소화다. 여러 기능을 한데 함축해 발열을 최소화했다. 따라서 AP 성능평가에선 저전력이 핵심이고 모든 요소와 기능이 곧 가격경쟁력으로 직결된다.

엑시노스가 가격경쟁력이 부족했다는 평가도 나온다. 엑시노스는 퀄컴보다 성능이 떨어지지만 미디어텍 대비 프리미엄 제품이란 인식이 강하다. 이런 와중에 퀄컴이 저가 마케팅을 지속하고 미디어텍이 저가 라인업을 강화하면서 상대적으로 엑시노스의 입지가 줄었다는 해석이다.

◇GPU 개선…긱벤치 멀티코어 벤치마크 우상향

삼성 시스템LSI부가 올 초 출시한 엑시노스2200에 준 가장 큰 변화는 'GPU 성능' 개선이다. 이전에 사용하던 ARM의 GPU인 '말리'(Mali) 대신 AMD와 공동 개발한 'RDNA2' 아키텍쳐 기반 GPU(mRDNA)를 탑재했다. 그동안 퀄컴 스냅드래곤의 제품 대비 전력소모가 높고 GPU 성능이 뒤떨어진다는 업계의 평가를 수렴해 2019년부터 AMD와 협업을 추진했다.

퀄컴은 2008년 AMD의 모바일 GPU사업부를 인수한 뒤 자체 GPU인 Adreno를 채택해 꾸준히 업그레이드해 왔다. 반면 삼성은 ARM의 Mali GPU를 그대로 적용하면서 GPU 성능이 떨어진 탓에 전력소비가 컸다. 고성능 게임 이용시 발열문제가 꾸준히 제기돼 왔던 배경이다.


삼성과 AMD의 협업은 긍정적이었다. 그간 모뎀 규격 이유로 반대 입장을 표했던 버라이즌, 차이나모바일 등 통신사들도 삼성 MX(세트부문)사업부에 AMD GPU를 탑재한 엑시노스 AP 요구했다는 점 역시 GPU 성능개선을 방증한 부분이다.

IT 정보 유출자(팁스터) '트론'(＠FrontTron)는 앞서 엑시노스2200의 GPU 지속성 성능이 전작 엑시노스2100보다 최대 성능은 31~34%, 지속 성능은 17~20%가량 앞선다고 주장하기도 했다.

엑시노스2200 공개 당시 유출됐던 긱벤치 평가 결과를 보면 싱글코어, 멀티코어 벤치마크 점수가 전반적으로 상향됐다. 퀄컴과 비교하면 점수가 낮지만 자체 엑시노스 추이만 놓고 보면 꾸준히 개선되는 양상이다. 긱벤치는 AP의 중앙처리장치(CPU)와 그래픽프로세서(GPU) 성능을 평가하는 툴이다. 싱글코어보다 멀티코어 부문에서 크게 개선된 모습이다. 멀티코어는 CPU, GPU, 전력소비, 지속성, 앱구동 등을 전반적으로 평가한 지표다.

엑시노스2200의 CPU가 전작과 스펙이 비슷하다는 점을 고려하면 멀티코어 벤치마크 개선엔 GPU 개선이 크게 반영됐을 가능성이 높다. 삼성 AP는 영국 ARM 설계를 사용한다. ARM은 전성비(전력대비 성능)이 뛰어나다는 점 때문에 애플, 퀄컴, 미디어텍 등 다수의 팹리스 업체들도 자사 AP에 탑재하고 있다.

사실상 긱벤치 점수 만으로 AP의 성능을 평가하는 건 무리가 있다. AP 칩셋 내부에 CPU나 GPU 블록 말고도 그래픽, 카메라, 통신 등 다양한 시스템들이 혼재돼 한 곳에 담겨 있다. 삼성전자는 엑시노스 2200 출시 당시 GPU, CPU에 대한 성능 개선에 대해선 언급 하지 않았다. 신경망처리장치(NPU) 연산 성능이 전작 대비 2배 이상 향상됐다는 점만 공개적으로 밝혔다.


◇퀄컴과 미디어텍 중간 포지션 '애매'

일각에선 가격 경쟁력이 약하다는 지적도 나온다. 구글의 안드로이드 진영(퀄컴, 미디어텍, 삼성전자)은 자체 운용체제(ios)를 보유한 애플과 달리 소프트웨어를 수정할 수 없다. 모두 ARM의 아키텍처를 사용하고 있지만 안드로이드 진영 팹리스사들은 오롯이 하드웨어의 성능에 좌우될 수 밖에 없다.

시장에서 삼성의 엑시노스(프리미엄)는 퀄컴의 스냅드래곤보다 성능이 낮지만 미디어텍 보다는 높은 것으로 인지된다. 하지만 수율에서 앞선 퀄컴이 가격 경쟁력을 확보하고 미디어텍이 가성비 마케팅으로 시장을 공략하면서 상대적으로 경쟁력이 떨어졌다는 평가다.

엑시노스는 성능 개선에 주력해 퀄컴과의 멀티코어 벤치마크 격차를 2020년 753점에서 2021년 55점으로 좁혔다. CPU와 GPU이 성능은 전년대비 30%, 40% 이상 향상시켰다. 하지만 점유율은 2018년 48%에서 2020년 36%, 2021년엔 20%대로 하락했다.

IT업계에서는 TSMC 공정에 최적화됐던 AMD의 아키텍처를 삼성 파운드리로 옮기는 과정에서 생긴 발열 이슈도 경쟁력 하락의 배경으로 지목한다. 엑시노스2200가 1.9㎓(기가헤르츠) 클록 속도를 갖고 있다 하지만 실제론 발열로 1.29㎓ 정도만 실행할 수 있었다는 주장이 제기됐다. 실제 삼성 MX사업부에서 GOS 옵션을 걸었다는 이유로 긱벤치에서도 퇴출된 상태다.
"""
doc=doc_with_newlines.replace(".", "\n")
doc=doc.replace("'", "")
doc=doc.replace('"', "")
doc=doc.replace("“", "")
doc=doc.replace("”", "")
doc=doc.replace("‘", "")
doc=doc.replace("’", "")
#문장을 분리하였지만, 아직 앞뒤 공백이 있음
temp_texts =  doc.split('\n')
#앞뒤 공백이 제거된 문자열들이 저장되는 list
texts=[]
for text in temp_texts:
    text = text.strip()
    if text is not '':
        texts.append(text)

print(texts)
# Out:
# ['삼성전자의 모바일 애플리케이션 프로세서(AP) 신작 엑시노스2200 점유율 하락 원인은 무엇일까', '세트사들이 선택하지 않은 데는 수율, 가격 등 여러 요인이 있겠지만 성능 측면으로 보면 전작(엑시노스2100, 엑시노스980)에 비해 개선된 부분이 확실히 존재한다', '판단근거는 글로벌 IT부품 성능측정 기관인 긱벤치(Geekbench5) 등의 벤치마크 결과다', '멀티코어 벤치마크(CPU, GPU, 전력소비, 지속성, 앱구동 등) 점수가 상향된 것으로 나타났다', '특히 GPU 지속력을 강화했다는 건 전력소비를 낮추는데 유리하게 작용한다', '세트사 입장에선 충분히 가점요인이 될 수 있는 부분이다', '모바일AP 칩셋의 존재 이유도 사실상 전력소모 최소화다', '여러 기능을 한데 함축해 발열을 최소화했다', '따라서 AP 성능평가에선 저전력이 핵심이고 모든 요소와 기능이 곧 가격경쟁력으로 직결된다', '엑시노스가 가격경쟁력이 부족했다는 평가도 나온다', '엑시노스는 퀄컴보다 성능이 떨어지지만 미디어텍 대비 프리미엄 제품이란 인식이 강하다', '이런 와중에 퀄컴이 저가 마케팅을 지속하고 미디어텍이 저가 라인업을 강화하면서 상대적으로 엑시노스의 입지가 줄었다는 해석이다', '◇GPU 개선…긱벤치 멀티코어 벤치마크 우상향', '삼성 시스템LSI부가 올 초 출시한 엑시노스2200에 준 가장 큰 변화는 GPU 성능 개선이다', '이전에 사용하던 ARM의 GPU인 말리(Mali) 대신 AMD와 공동 개발한 RDNA2 아키텍쳐 기반 GPU(mRDNA)를 탑재했다', '그동안 퀄컴 스냅드래곤의 제품 대비 전력소모가 높고 GPU 성능이 뒤떨어진다는 업계의 평가를 수렴해 2019년부터 AMD와 협업을 추진했다', '퀄컴은 2008년 AMD의 모바일 GPU사업부를 인수한 뒤 자체 GPU인 Adreno를 채택해 꾸준히 업그레이드해 왔다', '반면 삼성은 ARM의 Mali GPU를 그대로 적용하면서 GPU 성능이 떨어진 탓에 전력소비가 컸다', '고성능 게임 이용시 발열문
# ...

# %%
# 품사 태깅
tokenized_doc = hannanum.pos(doc)
# 형태소 분석기를 통해 명사 추출한 문서를 만듦
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc
                   if (word[1] == 'N' or word[1] == 'F')
                   and not word[0].isdigit() 
                   and len(word[0])>1
                   and word[0] not in stop_words])

n_gram_range = (1, 1)
# CountVectorizer를 사용하여 n-gram을 추출(n_gram_range에 해당하는)
count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

count_dict = set([(token, doc.count(token)) for token in candidates ])

ranked_words = sorted(count_dict, key=lambda x:x[1], reverse=True)
keywords= list([keyword for keyword, freq in ranked_words])

print(keywords)
# Out:
# ['성능', '엑시노스', '삼성', '퀄컴', '개선', '평가', '멀티코', '미디어텍', '멀티코어', '지속', '엑시노스2200', '긱벤치', '벤치마크', '경쟁력', '대비', '가격', '점수', '발열', '전작', '모바', '전력소비', '자체', '지속성', '삼성전자', '하락', '퀄컴과', '애플', '상향', '탑재', '사업부', '이유', '사용', '부분', '싱글코', '출시', '엑시노스2100', '수율', '시장', '제품', '점유율', '업계', '아키텍처', '스냅드래곤', '2020년', '강화', '배경', '주장', '최소', '유출', '그래픽', '실제', '프로세서', '앱구동', '팹리스', '향상', '저가', '존재', '제기', '결과', '최소화', '통신', '프리미엄', '기능', '진영', '전반적', '칩셋', '가격경쟁력', '세트사', '공개', '상대적', '싱글코어', '전력소모', '부문', '입장', '당시', '요인', '협업', '사실상', '안드로이드', '2021년', '마케팅', '하드웨어', '판단근거', '애플리케이션', '세트사들', '중간', '옵션', '긱벤치에서', '운용체제', '측면', '혼재', '상태', '격차', '원인', '지적', '탑재한', '방증', '2배', '언급', '반면', '55점', '부품', '적용', '이용시', '강하', '포지션', '확보', '753점', '가능성', '유출자', '실행', '영국', '구글', '채택', '수정', '이전', '버라이즌', '2008년', '변화', '보유', '인지', '정보', '직결', '긍정적', '함축', '성능측정', '무리', '연산', '전력대비', '비교', '카메라', '라인업', '팹리스사들', '모뎀', '가성비', '엑시노스980', '작용', '지목', '과정', '기관', '추이', '지속력', '전년대비', '업체들', '설계', '개발한', '공개적',
# ...
